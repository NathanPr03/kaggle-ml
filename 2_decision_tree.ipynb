# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

# Path of the file to read
iowa_file_path = './data/iowa_house_data.csv'

home_data = pd.read_csv(iowa_file_path)

# print(home_data.columns)

y = home_data.SalePrice # By convention, 'y' is the target variable

feature_names = ['LotArea',
'YearBuilt',
'1stFlrSF',
'2ndFlrSF',
'FullBath',
'BedroomAbvGr',
'TotRmsAbvGrd']

X = home_data[feature_names] # By convention, 'X' is th feature matrix. i.e. the things (features) that influence what the model is trying to predict (target)

# print(X.describe)
# print the top few lines
# print(X.head)

#For model reproducibility, set a numeric value for random_state when specifying the model
iowa_model = DecisionTreeRegressor(random_state=1)

# fit ingests the training data and learns the relationship between X and y
iowa_model.fit(X, y)

predictions = iowa_model.predict(X)
print(abs(sum(predictions)/len(predictions) - sum(y)/len(y)))
# Out:
# 0.0

# %% [markdown]
# So the above will train on the whole dataset, which leaves us nothing to evaluate the model on. This is called "training on the test set" and is a big no-no. So lets split them up

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# Split data into training and validation sets
X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state=1)

# Fit model on training data
iowa_model.fit(X_train, y_train)

# Predict on validation data
val_predictions = iowa_model.predict(X_valid)

for i in range(len(X_valid)):
    print(f"Predicted: {val_predictions[i]}, Actual: {y_valid.iloc[i]}")

# Compare predictions to actual values
mae = mean_absolute_error(y_valid, val_predictions)
print(f"Mean Absolute Error: {mae}")
# Out:
# Predicted: 186500.0, Actual: 231500
# Predicted: 184000.0, Actual: 179500
# Predicted: 130000.0, Actual: 122000
# Predicted: 92000.0, Actual: 84500
# Predicted: 164500.0, Actual: 142000
# Predicted: 220000.0, Actual: 325624
# Predicted: 335000.0, Actual: 285000
# Predicted: 144152.0, Actual: 151000
# Predicted: 215000.0, Actual: 195000
# Predicted: 262000.0, Actual: 275000
# Predicted: 180000.0, Actual: 175000
# Predicted: 121000.0, Actual: 61000
# Predicted: 175900.0, Actual: 174000
# Predicted: 210000.0, Actual: 385000
# Predicted: 248900.0, Actual: 230000
# Predicted: 131000.0, Actual: 87000
# Predicted: 100000.0, Actual: 125000
# Predicted: 149350.0, Actual: 98600
# Predicted: 235000.0, Actual: 260000
# Predicted: 156000.0, Actual: 143000
# Predicted: 149900.0, Actual: 124000
# Predicted: 265979.0, Actual: 122500
# Predicted: 193500.0, Actual: 236500
# Predicted: 377500.0, Actual: 337500
# Predicted: 100000.0, Actual: 76000
# Predicted: 162900.0, Actual: 187000
# Predicted: 145000.0, Actual: 128000
# Predicted: 180000.0, Actual: 179000
# Predicted: 582933.0, Actual: 485000
# Predicted: 146000.0, Actual: 122500
# Predicted: 140000.0, Actual: 106000
# Predicted: 91500.0, Actual: 118000
# Predicted: 112500.0, Actual: 127000
# Predicted: 113000.0, Actual: 80000
# Predicted: 145000.0, Actual: 153000
# Predicted: 312500.0, Actual: 360000
# Predicted: 110000.0, Actual: 132000
# Predicted: 132000.0, Actual: 85500
# Predicted: 305000.0, Actual: 262280
# Predicted: 128000.0, Actual: 112000
# Predicted: 162900.0, Actual: 131000
# Predicted: 115000.0, Actual: 139000
# Predicted: 110000.0, Actual: 87000
# Predicted: 124000.0, Actual: 135000
# Predicted: 215200.0, Actual: 181000
# Predicted: 180000.0, Actual: 163500
# Predicted: 79000.0, Actual: 116900
# Predicted: 192000.0, Actual: 159895
# Predicted: 282922.0, Actual: 244600
# Predicted: 235000.0, Actual: 294000
# Predicted: 132000.0, Actual: 97000
# Predicted: 325000.0, Actual: 295000
# Predicted: 80000.0, Actual: 120500
# Predicted: 237000.0, Actual: 239500
# Predicted: 208300.0, Actual: 194000
# Predicted: 100000.0, Actual: 115000
# Predicted: 120500.0, Actual: 119500
# Predicted: 162000.0, Actual: 180000
# Predicted: 153000.0, Actual: 118000
# Predicted: 187000.0, Actual: 178000
# Predicted: 185750.0, Actual: 167000
# Predicted: 335000.0, Actual: 267000
# Predicted: 129000.0, Actual: 82000
# Predicted: 124900.0, Actual: 133900
# Predicted: 185750.0, Actual: 167000
# Predicted: 133700.0, Actual: 132500
# Predicted: 127000.0, Actual: 135000
# Predicted: 230000.0, Actual: 248000
# Predicted: 146800.0, Actual: 160000
# Predicted: 157900.0, Actual: 144500
# Predicted: 136000.0, Actual: 200500
# Predicted: 153575.0, Actual: 113000
# Predicted: 335000.0, Actual: 354000
# Predicted: 177500.0, Actual: 164000
# Predicted: 143000.0, Actual: 170000
# Predicted: 202500.0, Actual: 224000
# Predicted: 168500.0, Actual: 163900
# Predicted: 105000.0, Actual: 160000
# Predicted: 305900.0, Actual: 466500
# Predicted: 192000.0, Actual: 172500
# Predicted: 190000.0, Actual: 193500
# Predicted: 140200.0, Actual: 133000
# Predicted: 134900.0, Actual: 137000
# Predicted: 128950.0, Actual: 167500
# Predicted: 213000.0, Actual: 196500
# Predicted: 108959.0, Actual: 146000
# Predicted: 149500.0, Actual: 159500
# Predicted: 190000.0, Actual: 158000
# Predicted: 175900.0, Actual: 189000
# Predicted: 160000.0, Actual: 172500
# Predicted: 250580.0, Actual: 194201
# Predicted: 157000.0, Actual: 181000
# Predicted: 120500.0, Actual: 115000
# Predicted: 147500.0, Actual: 101800
# Predicted: 118000.0, Actual: 100000
# Predicted: 117000.0, Actual: 139000
# Predicted: 110000.0, Actual: 115000
# Predicted: 130000.0, Actual: 139000
# Predicted: 148500.0, Actual: 156000
# Predicted: 148000.0, Actual: 158000
# Predicted: 190000.0, Actual: 172000
# Predicted: 130500.0, Actual: 138000
# Predicted: 127000.0, Actual: 125500
# Predicted: 120500.0, Actual: 123000
# Predicted: 135000.0, Actual: 134500
# Predicted: 168000.0, Actual: 163000
# Predicted: 176432.0, Actual: 169990
# Predicted: 128000.0, Actual: 140000
# Predicted: 147000.0, Actual: 140000
# Predicted: 260000.0, Actual: 325000
# Predicted: 132000.0, Actual: 157500
# Predicted: 129500.0, Actual: 225000
# Predicted: 171000.0, Actual: 107000
# Predicted: 181134.0, Actual: 185500
# Predicted: 227875.0, Actual: 239900
# Predicted: 189000.0, Actual: 163990
# Predicted: 282922.0, Actual: 201000
# Predicted: 94750.0, Actual: 127000
# Predicted: 185000.0, Actual: 172500
# Predicted: 194000.0, Actual: 228000
# Predicted: 159000.0, Actual: 117000
# Predicted: 279500.0, Actual: 232600
# Predicted: 290000.0, Actual: 403000
# Predicted: 135000.0, Actual: 169500
# Predicted: 299800.0, Actual: 151400
# Predicted: 165000.0, Actual: 180000
# Predicted: 394432.0, Actual: 370878
# Predicted: 135750.0, Actual: 55993
# Predicted: 155000.0, Actual: 207500
# Predicted: 212000.0, Actual: 224500
# Predicted: 310000.0, Actual: 280000
# Predicted: 134800.0, Actual: 82000
# Predicted: 84000.0, Actual: 137000
# Predicted: 122900.0, Actual: 130500
# Predicted: 80000.0, Actual: 73000
# Predicted: 191000.0, Actual: 217000
# Predicted: 755000.0, Actual: 625000
# Predicted: 147000.0, Actual: 367294
# Predicted: 248000.0, Actual: 230000
# Predicted: 106500.0, Actual: 142000
# Predicted: 145000.0, Actual: 115000
# Predicted: 359100.0, Actual: 272000
# Predicted: 145000.0, Actual: 176500
# Predicted: 192500.0, Actual: 234000
# Predicted: 149000.0, Actual: 40000
# Predicted: 252000.0, Actual: 213500
# Predicted: 109000.0, Actual: 126000
# Predicted: 215000.0, Actual: 187100
# Predicted: 220000.0, Actual: 200000
# Predicted: 138500.0, Actual: 117500
# Predicted: 185000.0, Actual: 176000
# Predicted: 185000.0, Actual: 174000
# Predicted: 120500.0, Actual: 97000
# Predicted: 181000.0, Actual: 169000
# Predicted: 173000.0, Actual: 154000
# Predicted: 335000.0, Actual: 361919
# Predicted: 67000.0, Actual: 85000
# Predicted: 149350.0, Actual: 134000
# Predicted: 67000.0, Actual: 96500
# Predicted: 156000.0, Actual: 127000
# Predicted: 119000.0, Actual: 60000
# Predicted: 110500.0, Actual: 108480
# Predicted: 184000.0, Actual: 151000
# Predicted: 147000.0, Actual: 135000
# Predicted: 156000.0, Actual: 99500
# Predicted: 171000.0, Actual: 124000
# Predicted: 177000.0, Actual: 177500
# Predicted: 159000.0, Actual: 144000
# Predicted: 125000.0, Actual: 119000
# Predicted: 105000.0, Actual: 107500
# Predicted: 284000.0, Actual: 254900
# Predicted: 167500.0, Actual: 180500
# Predicted: 200000.0, Actual: 222000
# Predicted: 312500.0, Actual: 271000
# Predicted: 213000.0, Actual: 181000
# Predicted: 135960.0, Actual: 140000
# Predicted: 205000.0, Actual: 158000
# Predicted: 237000.0, Actual: 204750
# Predicted: 107000.0, Actual: 135000
# Predicted: 163000.0, Actual: 161500
# Predicted: 132500.0, Actual: 128500
# Predicted: 155835.0, Actual: 179540
# Predicted: 165500.0, Actual: 143000
# Predicted: 138500.0, Actual: 147000
# Predicted: 257000.0, Actual: 280000
# Predicted: 160000.0, Actual: 131500
# Predicted: 394617.0, Actual: 253293
# Predicted: 281213.0, Actual: 317000
# Predicted: 161000.0, Actual: 210000
# Predicted: 127500.0, Actual: 120000
# Predicted: 88000.0, Actual: 110000
# Predicted: 139000.0, Actual: 127000
# Predicted: 89500.0, Actual: 106000
# Predicted: 132500.0, Actual: 172500
# Predicted: 134800.0, Actual: 166000
# Predicted: 335000.0, Actual: 258000
# Predicted: 248900.0, Actual: 213000
# Predicted: 155000.0, Actual: 150000
# Predicted: 147000.0, Actual: 158500
# Predicted: 86000.0, Actual: 82500
# Predicted: 185000.0, Actual: 212000
# Predicted: 200000.0, Actual: 238000
# Predicted: 180500.0, Actual: 158000
# Predicted: 215200.0, Actual: 178000
# Predicted: 319900.0, Actual: 328900
# Predicted: 105000.0, Actual: 110000
# Predicted: 194000.0, Actual: 185000
# Predicted: 340000.0, Actual: 320000
# Predicted: 256000.0, Actual: 315000
# Predicted: 280000.0, Actual: 228950
# Predicted: 186500.0, Actual: 180000
# Predicted: 105500.0, Actual: 117000
# Predicted: 155000.0, Actual: 176000
# Predicted: 133500.0, Actual: 111250
# Predicted: 255500.0, Actual: 297000
# Predicted: 253000.0, Actual: 266000
# Predicted: 130000.0, Actual: 130000
# Predicted: 92900.0, Actual: 93500
# Predicted: 256000.0, Actual: 186700
# Predicted: 100000.0, Actual: 91000
# Predicted: 755000.0, Actual: 745000
# Predicted: 138500.0, Actual: 62383
# Predicted: 168500.0, Actual: 172500
# Predicted: 112000.0, Actual: 170000
# Predicted: 127000.0, Actual: 119000
# Predicted: 109008.0, Actual: 129900
# Predicted: 197000.0, Actual: 210000
# Predicted: 245500.0, Actual: 173000
# Predicted: 171900.0, Actual: 164500
# Predicted: 162000.0, Actual: 170000
# Predicted: 128000.0, Actual: 125500
# Predicted: 173000.0, Actual: 183000
# Predicted: 132000.0, Actual: 103000
# Predicted: 118000.0, Actual: 141500
# Predicted: 235128.0, Actual: 315500
# Predicted: 118964.0, Actual: 118858
# Predicted: 260000.0, Actual: 290000
# Predicted: 116000.0, Actual: 119000
# Predicted: 185000.0, Actual: 104900
# Predicted: 315750.0, Actual: 348000
# Predicted: 236500.0, Actual: 374000
# Predicted: 140000.0, Actual: 200100
# Predicted: 151500.0, Actual: 132250
# Predicted: 184000.0, Actual: 161500
# Predicted: 84000.0, Actual: 131500
# Predicted: 130000.0, Actual: 104000
# Predicted: 154000.0, Actual: 132500
# Predicted: 205000.0, Actual: 133000
# Predicted: 110000.0, Actual: 170000
# Predicted: 151500.0, Actual: 180000
# Predicted: 123000.0, Actual: 130000
# Predicted: 129500.0, Actual: 125000
# Predicted: 173900.0, Actual: 186500
# Predicted: 181500.0, Actual: 171500
# Predicted: 165500.0, Actual: 100000
# Predicted: 106500.0, Actual: 114500
# Predicted: 184900.0, Actual: 173000
# Predicted: 84500.0, Actual: 86000
# Predicted: 377500.0, Actual: 320000
# Predicted: 118500.0, Actual: 133000
# Predicted: 180000.0, Actual: 220000
# Predicted: 190000.0, Actual: 137900
# Predicted: 208500.0, Actual: 224900
# Predicted: 181000.0, Actual: 153500
# Predicted: 98000.0, Actual: 115000
# Predicted: 157000.0, Actual: 207500
# Predicted: 151500.0, Actual: 113000
# Predicted: 84000.0, Actual: 178400
# Predicted: 139000.0, Actual: 140000
# Predicted: 100000.0, Actual: 83000
# Predicted: 161750.0, Actual: 197000
# Predicted: 165600.0, Actual: 187500
# Predicted: 116000.0, Actual: 81000
# Predicted: 118500.0, Actual: 93500
# Predicted: 187000.0, Actual: 197500
# Predicted: 147000.0, Actual: 93000
# Predicted: 112000.0, Actual: 106000
# Predicted: 132000.0, Actual: 144000
# Predicted: 230000.0, Actual: 220000
# Predicted: 128000.0, Actual: 144900
# Predicted: 147000.0, Actual: 139000
# Predicted: 125000.0, Actual: 132000
# Predicted: 145000.0, Actual: 149000
# Predicted: 151000.0, Actual: 153500
# Predicted: 284000.0, Actual: 263435
# Predicted: 221000.0, Actual: 205000
# Predicted: 140200.0, Actual: 132500
# Predicted: 129000.0, Actual: 103200
# Predicted: 290000.0, Actual: 249700
# Predicted: 105000.0, Actual: 64500
# Predicted: 96500.0, Actual: 83000
# Predicted: 310000.0, Actual: 339750
# Predicted: 140000.0, Actual: 145900
# Predicted: 132000.0, Actual: 106250
# Predicted: 203000.0, Actual: 164990
# Predicted: 221000.0, Actual: 228500
# Predicted: 215200.0, Actual: 193000
# Predicted: 214000.0, Actual: 244000
# Predicted: 139000.0, Actual: 159950
# Predicted: 91500.0, Actual: 119000
# Predicted: 148000.0, Actual: 160000
# Predicted: 155000.0, Actual: 147000
# Predicted: 115000.0, Actual: 134450
# Predicted: 180000.0, Actual: 174000
# Predicted: 165500.0, Actual: 144000
# Predicted: 223000.0, Actual: 190000
# Predicted: 139000.0, Actual: 160000
# Predicted: 179900.0, Actual: 175000
# Predicted: 150000.0, Actual: 135000
# Predicted: 185000.0, Actual: 176000
# Predicted: 163000.0, Actual: 168500
# Predicted: 176000.0, Actual: 139000
# Predicted: 127000.0, Actual: 102776
# Predicted: 227000.0, Actual: 221500
# Predicted: 146000.0, Actual: 148500
# Predicted: 99900.0, Actual: 55000
# Predicted: 275000.0, Actual: 281000
# Predicted: 180500.0, Actual: 179900
# Predicted: 180000.0, Actual: 182900
# Predicted: 157000.0, Actual: 217500
# Predicted: 186500.0, Actual: 195000
# Predicted: 179900.0, Actual: 154000
# Predicted: 137500.0, Actual: 124900
# Predicted: 219500.0, Actual: 228000
# Predicted: 155000.0, Actual: 125000
# Predicted: 345000.0, Actual: 438780
# Predicted: 197000.0, Actual: 160200
# Predicted: 205000.0, Actual: 271000
# Predicted: 159000.0, Actual: 113000
# Predicted: 159434.0, Actual: 103600
# Predicted: 156000.0, Actual: 119500
# Predicted: 196000.0, Actual: 275000
# Predicted: 252678.0, Actual: 250000
# Predicted: 255500.0, Actual: 306000
# Predicted: 213000.0, Actual: 168000
# Predicted: 150900.0, Actual: 136905
# Predicted: 143750.0, Actual: 128000
# Predicted: 139000.0, Actual: 107000
# Predicted: 260000.0, Actual: 341000
# Predicted: 189000.0, Actual: 176000
# Predicted: 213250.0, Actual: 224900
# Predicted: 207500.0, Actual: 289000
# Predicted: 80000.0, Actual: 79900
# Predicted: 221000.0, Actual: 274000
# Predicted: 109500.0, Actual: 109900
# Predicted: 155000.0, Actual: 175000
# Predicted: 165000.0, Actual: 166000
# Predicted: 149350.0, Actual: 151000
# Predicted: 204900.0, Actual: 264132
# Predicted: 105900.0, Actual: 79500
# Predicted: 155000.0, Actual: 241000
# Predicted: 176000.0, Actual: 141000
# Predicted: 395000.0, Actual: 377426
# Predicted: 149700.0, Actual: 132000
# Predicted: 147000.0, Actual: 141000
# Predicted: 143900.0, Actual: 136500
# Predicted: 226700.0, Actual: 205950
# Predicted: 176000.0, Actual: 157000
# Predicted: 116000.0, Actual: 93000
# Predicted: 325300.0, Actual: 309000
# Predicted: 133750.0, Actual: 187500
# Predicted: 188500.0, Actual: 178000
# Predicted: 148500.0, Actual: 125000
# Predicted: 284000.0, Actual: 232000
# Predicted: 201800.0, Actual: 135000
# Mean Absolute Error: 29652.931506849316

# %% [markdown]
# Now we have a way to evaluate the model, lets try and improve it. We can modify the tree depth of the decision tree. Too high a depth and we overfit, too low and we underfit. Lets try a few depths:

# %%
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)


candidate_max_leaf_nodes = [5, 25, 50, 100, 250, 500]
depth_and_mae = {}

for depth in candidate_max_leaf_nodes:
    depths_mae = get_mae(depth, X_train, X_valid, y_train, y_valid)
    depth_and_mae[depth] = depths_mae


best_tree_size = min(depth_and_mae, key=depth_and_mae.get)

print(best_tree_size)
# Out:
# 100

# %% [markdown]
# Now we have the best tree size, lets fit a model on the whole dataset and make some predictions

# %%
final_model = DecisionTreeRegressor(max_leaf_nodes=best_tree_size, random_state=1)
final_model.fit(X, y)

final_predictions = final_model.predict(X)
print(final_predictions)
# Out:
# [209133.65384615 146415.0075188  209133.65384615 ... 238763.63636364
#  130629.         146415.0075188 ]
